# %% [markdown]
# https://www.analyticsvidhya.com/blog/2021/12/text-classification-of-news-articles/

# %%
# %store -r df

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %% [markdown]
# Explore data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4480 entries, 0 to 4479
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   headline       4480 non-null   object
#  1   date           4480 non-null   object
#  2   doc_type       4480 non-null   object
#  3   material_type  4480 non-null   object
#  4   section        0 non-null      object
#  5   keywords       4480 non-null   object
# dtypes: object(6)
# memory usage: 210.1+ KB

# %%
df['keywords'] = df['keywords'].astype(str)

# %%
pd.set_option('display.max_rows', df.shape[0]+1)

# %%
headline = df['headline']

# %%
string = ''

# %%
for i in headline:
    string += ' '+ i

# %%
print(string)
# Out:
#  ‘Battling a Demon’: Drifter Sought Help Before Texas Church Shooting Protect Veterans From Fraud F.D.A. Plans to Ban Most E-Cigarette Flavors but Menthol ‘It’s Green and Slimy’ Corrections: Jan. 1, 2020 Quotation of the Day: Ex-SEAL Now Pitching Products and President Hospitals and Schools Are Being Bombed in Syria. A U.N. Inquiry Is Limited. We Took a Deeper Look. Hong Kong Protesters Return to Streets as New Year Begins Kevin Spacey Accuser’s Estate Drops Sexual Assault Lawsuit Dizzying Day for Trump Caps a Year Full of Them Meteor Showers in 2020 That Will Light Up Night Skies Sync your calendar with the solar system Rocket Launches, Trips to Mars and More 2020 Space and Astronomy Events What’s on TV Wednesday: A Linda Ronstadt Doc and ‘Doctor Who’ How the U.S. Embassy in Iraq Became a Target 10 Electric Vehicles to Watch Why the Fires in Australia Are So Bad Pro-Iranian Protesters End Siege of U.S. Embassy in Baghdad Judge John Hodgman on Uncle Money Bags She Felt Fine, but Her M.R.I. Showed Several Strokes. What Was Wrong? These Armenian Flatbreads Stuffed With Greens Are the Perfect Snack ‘Don’t Believe a Word,’ a Look at Language and Power (and Why Dolphins Have Accents) Eat Better, Feel Better? Food Advice From the Year in Well Can You Talk Your Way Out of a Life Sentence? Poem: The Far Norway Maples New Year’s Resolution: Be More Honest No More Excuses Not to Exercise New Cruise Ships to Set Sail for Antarctica The Tech That Will Invade Our Lives in 2020 Inside the Fake Igloo Rooftop Wars Adam Driver Has Put Everything He’s Got Onscreen Couture Creations for Dancing Bodies 100 Years Ago, the Booziest January Suddenly Dried Up Elizabeth Warren Isn’t Talking Much About ‘Medicare for All’ Anymore Living In ... Bedminster, N.J. In a Homecoming Video Meant to Unite Campus, Almost Everyone Was White Bedminster, N.J.: Horses, Golf and Presidential Visits China Moves to Steady Its Slowing Economic Growth Pete Buttigieg’s Campaign Says It Raised $24.7 Million in the Fourth Quarter The Work Diary of Anna Bond, Whose Work Includes … Making Diaries Pika-Who? How Pokémon Go Confused the Canadian Military What Kim Jong-un’s Latest Threats Say About His Trump Strategy Mexico Prison Fight Leaves at Least 16 Inmates Dead What You Get for $750,000 $750,000 Homes in Mississippi, Missouri and Arizona Netanyahu Seeks Immunity From Israeli Corruption Charges Restored 19th-Century Elegance in Northwestern Spain House Hunting in Spain: A Historic Estate For Under $2 Million Pope Francis Apologizes After Slapping Away a Clinging Pilgrim Fearless Predictions for the N.B.A. in 2020 One Startling Scene: Tracy Letts in ‘Ford v Ferrari’ Simon Stone Faced the Unthinkable. He Thinks You Should Too. Reading ‘Us’ Through Its T-shirts New Year, New Recipes Stories About Equality that Gave Us Hope in 2019 ‘A Quiet Place Part II’ First Trailer: Why Is It So Noisy? North Korea Is Not Done Trolling Trump Flying Lanterns Probably Caused Zoo Fire in Germany, Police Say Coaching Female Athletes, and Gender Inequality There Will Be Blood. And It Will Be in Your Face. Can Collectors: Nuisance or Public Service? 2020 Golden Globes Predictions: Which Movies Will Win? Money, Rage and Love Rethinking How We Choose Candidates A Restaurant With No Leftovers A.I. Is Learning to Read Mammograms New Injection Method Makes an Old TB Vaccine Far More Powerful More People Are Dying on New York City’s Streets. What Went Wrong? Trump Bet He Could Isolate Iran and Charm North Korea. It’s Not That Easy. Review: Anna Netrebko Rings in the Year With a Met Gala Woody Vasulka, Whose Video Art Extended Boundaries, Dies at 82 Fazle Abed, Founder of a Leading Relief Agency, Dies at 83 The Lesson of an Albanian Earthquake: The Balkans Aren’t Ready for the Big One 20 Books We’re Watching For in 2020 Only You Can Prevent Dystopia Every Moment With My Son Is an Act of Creation 90,000 Jews Gather to Pray and Defy a Wave of Hate Shock Waves From American Airstrikes in Iraq May Have Just B ...

# %%
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(string)

# %%
fig = plt.figure(figsize=(10, 10))

# %%
fig.imshow(word_cloud, interpolation='bilinear')
fig.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4764/611317192.py in <module>
# ----> 1 fig.imshow(word_cloud, interpolation='bilinear')
#       2 fig.axis("off")
#       3 plt.show()
#
# AttributeError: 'Figure' object has no attribute 'imshow'
