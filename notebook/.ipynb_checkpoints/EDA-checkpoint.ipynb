# %% [raw]
# ---
# title: EDA
# author: Wan&Heng
# description: For checking my project
# ---

# %% [markdown]
# https://www.analyticsvidhya.com/blog/2021/12/text-classification-of-news-articles/

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Marwan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
path = '../wordcloud_style/'
font = path+'Chomsky.otf'
pics = path+'pics.png'

# %% [markdown]
# #### import data from cleansing

# %%
df = pd.read_csv('../data/cleaned/cleaned-data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2341 entries, 0 to 2340
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         2341 non-null   object
#  1   category_id  2341 non-null   int64
#  2   category     2341 non-null   object
#  3   headline     2341 non-null   object
#  4   articles     2341 non-null   object
#  5   url          2341 non-null   object
#  6   op           2341 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 128.1+ KB

# %%
df[['category_id', 'category']].drop_duplicates()
# Out:
#     category_id  category
# 0             0   opinion
# 1             1     world
# 3             2  politics
# 4             3      arts
# 6             4  business
# 19            5    sports

# %% [markdown]
# #### Pie chart

# %%
fig = plt.figure(figsize = (5,5))
colors = ["skyblue"]
opinion = df[df['category_id'] == 0 ]
world = df[df['category_id'] == 1]
politics = df[df['category_id'] == 2]
arts = df[df['category_id'] == 3]
business = df[df['category_id'] == 4]
sports = df[df['category_id'] == 5]
count = [business['category_id'].count(), opinion['category_id'].count(), politics['category_id'].count(), sports['category_id'].count(), arts['category_id'].count(), world['category_id'].count()]
pie = plt.pie(count, labels = ['business', 'opinion', 'politics', 'sports', 'arts', 'world'],
              autopct = "%1.1f%%",
              shadow = True,
              colors = colors,
              startangle = 45,
              explode = (0.05, 0.05, 0.05, 0.05,0.05, 0.05))

# %% [markdown]
# #### Word Cloud

# %%
from wordcloud import WordCloud

stop = set(stopwords.words('english'))
opinion = df[df['category_id'] == 0 ]
world = df[df['category_id'] == 1]
politics = df[df['category_id'] == 2]
arts = df[df['category_id'] == 3]
business = df[df['category_id'] == 4]
sports = df[df['category_id'] == 5]

opinion = opinion['articles']
world = world['articles']
politics = politics['articles']
arts = arts['articles']
business = business['articles']
sports = sports['articles']

# %%
def wordcloud_draw(df, color = 'white'):
    words = ' '.join(df)
    cleaned_word = ' '.join([word for word in words.split()
    if (word != 'news' and word != 'articles')])
    wordcloud = WordCloud(stopwords = stop,
    background_color = color,
    width = 2500, height = 2500).generate(cleaned_word)
    plt.figure(1, figsize = (10,7))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
print("business related words:")
wordcloud_draw(business, 'white')
# Out:
# business related words:

# %%
print("politics related words:")
wordcloud_draw(politics, 'white')
# Out:
# politics related words:

# %%
print("opinion related words:")
wordcloud_draw(opinion, 'white')
# Out:
# opinion related words:

# %%
print("world related words:")
wordcloud_draw(world, 'white')
# Out:
# world related words:

# %%
print("sports related words:")
wordcloud_draw(sports, 'white')

# %%
print("arts related words:")
wordcloud_draw(arts, 'white')
