# %% [markdown]
# ปัญหาที่พบเจอ
# - คอลลัมพ์ Keywords เป็น list ที่แยกกัน

# %%
import pandas as pd
import re

# %% [markdown]
# #### import Data

# %%
df = pd.read_csv('../data/raw/raw-data.csv')

# %%
df
# Out:
#             date                                                url  \
# 0     2020-01-01  https://www.nytimes.com/2019/12/31/us/texas-ch...
# 1     2020-01-01  https://www.nytimes.com/2019/12/31/opinion/for...
# 2     2020-01-01  https://www.nytimes.com/2019/12/31/health/e-ci...
# 3     2020-01-01  https://www.nytimes.com/2019/12/31/crosswords/...
# 4     2020-01-01  https://www.nytimes.com/2019/12/31/pageoneplus...
# ...          ...                                                ...
# 4475  2020-01-31  https://www.nytimes.com/2020/01/31/sports/bask...
# 4476  2020-01-31  https://www.nytimes.com/2020/01/31/sports/olym...
# 4477  2020-01-31  https://www.nytimes.com/2020/01/31/health/cpr-...
# 4478  2020-01-31  https://www.nytimes.com/video/us/politics/1000...
# 4479  2020-01-31  https://www.nytimes.com/2020/01/31/nyregion/pr...
#
#                                                headline  \
# 0     ‘Battling a Demon’: Drifter Sought Help Before...
# ...

# %%
def count_values(dataframe ,a):
    '''
    a = ชื่อ column
    ฟั่งชั่นนับจำนวน Label ทั้งหมด
    Return = DataFrame 
    '''
    label = []
    u_names = []
    count = []
    for i in dataframe[a]:
        label.append(i)
    for names in label:
        if names not in u_names:
            names = str(names)
            u_names.append(names)
    for num in u_names:
        count.append(label.count(num))
    return pd.DataFrame({'Label': u_names, 'Numbers': count})

# %%
count_values(df ,'label')
# Out:
#               Label  Numbers
# 0                us      287
# 1           opinion      503
# 2            health       49
# 3        crosswords       43
# 4       todayspaper       28
# 5             world      482
# 6          politics      494
# 7           science       61
# 8              arts      346
# 9          business      297
# 10         magazine       67
# 11            books      173
# 12             well       56
# 13           travel       41
# 14       technology       59
# 15         nyregion      189
# 16           movies      134
# 17       realestate      109
# 18           sports      226
# 19          theater       64
# 20           dining      104
# 21            style      133
# 22        parenting        6
# 23         briefing      100
# 24          climate       27
# 25   smarter-living       16
# 26       obituaries       13
# 27         learning      115
# 28    reader-center       23
# 29         podcasts       30
# 30       t-magazine       26
# ...

# %%
df1 = df.copy(deep=True)

# %%
df1 = df[['date','label', 'headline', 'articles', 'url']]

# %%
df1
# Out:
#             date       label  \
# 0     2020-01-01          us
# 1     2020-01-01     opinion
# 2     2020-01-01      health
# 3     2020-01-01  crosswords
# 4     2020-01-01          us
# ...          ...         ...
# 4475  2020-01-31      sports
# 4476  2020-01-31      sports
# 4477  2020-01-31      health
# 4478  2020-01-31    politics
# 4479  2020-01-31    nyregion
#
#                                                headline  \
# 0     ‘Battling a Demon’: Drifter Sought Help Before...
# 1                           Protect Veterans From Fraud
# 2     F.D.A. Plans to Ban Most E-Cigarette Flavors b...
# 3                                ‘It’s Green and Slimy’
# 4                             Corrections: Jan. 1, 2020
# ...                                                 ...
# 4475  Lakers Fall to Blazers on Emotional Night Hono...
# 4476  Alberto Salazar Is Suspended by SafeSport Afte...
# 4477                                    CPR, by Default
# ...

# %%
df1 = df1.loc[df['label'].isin(['sports','opinion','world','politics','business','arts'])]

# %%
df1
# Out:
#             date     label                                           headline  \
# 1     2020-01-01   opinion                        Protect Veterans From Fraud
# 6     2020-01-01     world  Hospitals and Schools Are Being Bombed in Syri...
# 7     2020-01-01     world  Hong Kong Protesters Return to Streets as New ...
# 9     2020-01-01  politics    Dizzying Day for Trump Caps a Year Full of Them
# 13    2020-01-01      arts  What’s on TV Wednesday: A Linda Ronstadt Doc a...
# ...          ...       ...                                                ...
# 4473  2020-01-31  business  Richard Plepler and Josh Tyrangiel May Revive ...
# 4474  2020-01-31  politics      Trump Hotel Patrons Relish Impeachment Finale
# 4475  2020-01-31    sports  Lakers Fall to Blazers on Emotional Night Hono...
# 4476  2020-01-31    sports  Alberto Salazar Is Suspended by SafeSport Afte...
# 4478  2020-01-31  politics  Impeachment Trial Highlights: A Showdown Over ...
#
# ...

# %%
df1.shape
# Out:
# (2348, 5)

# %%
df.shape
# Out:
# (4480, 9)

# %%
count_values(df1 ,'label')
# Out:
#       Label  Numbers
# 0   opinion      503
# 1     world      482
# 2  politics      494
# 3      arts      346
# 4  business      297
# 5    sports      226

# %%
df1['category_id'] = df1['label'].factorize(sort=False)[0]
# Out:
# C:\Users\Marwan\AppData\Local\Temp/ipykernel_4432/580716838.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['category_id'] = df1['label'].factorize(sort=False)[0]

# %%
df1[['label','category_id']].drop_duplicates().sort_values('category_id')
# Out:
#        label  category_id
# 1    opinion            0
# 6      world            1
# 9   politics            2
# 13      arts            3
# 15  business            4
# 49    sports            5

# %%
df1 = df1[['date', 'category_id', 'label', 'headline', 'articles', 'url']]

# %%
df1
# Out:
#             date  category_id     label  \
# 1     2020-01-01            0   opinion
# 6     2020-01-01            1     world
# 7     2020-01-01            1     world
# 9     2020-01-01            2  politics
# 13    2020-01-01            3      arts
# ...          ...          ...       ...
# 4473  2020-01-31            4  business
# 4474  2020-01-31            2  politics
# 4475  2020-01-31            5    sports
# 4476  2020-01-31            5    sports
# 4478  2020-01-31            2  politics
#
#                                                headline  \
# 1                           Protect Veterans From Fraud
# 6     Hospitals and Schools Are Being Bombed in Syri...
# 7     Hong Kong Protesters Return to Streets as New ...
# 9       Dizzying Day for Trump Caps a Year Full of Them
# 13    What’s on TV Wednesday: A Linda Ronstadt Doc a...
# ...                                                 ...
# 4473  Richard Plepler and Josh Tyrangiel May Revive ...
# ...

# %%
df1 = df1.rename(index=str, columns = {"label" : "category"}, inplace=False)

# %%
df1
# Out:
#             date  category_id  category  \
# 1     2020-01-01            0   opinion
# 6     2020-01-01            1     world
# 7     2020-01-01            1     world
# 9     2020-01-01            2  politics
# 13    2020-01-01            3      arts
# ...          ...          ...       ...
# 4473  2020-01-31            4  business
# 4474  2020-01-31            2  politics
# 4475  2020-01-31            5    sports
# 4476  2020-01-31            5    sports
# 4478  2020-01-31            2  politics
#
#                                                headline  \
# 1                           Protect Veterans From Fraud
# 6     Hospitals and Schools Are Being Bombed in Syri...
# 7     Hong Kong Protesters Return to Streets as New ...
# 9       Dizzying Day for Trump Caps a Year Full of Them
# 13    What’s on TV Wednesday: A Linda Ronstadt Doc a...
# ...                                                 ...
# 4473  Richard Plepler and Josh Tyrangiel May Revive ...
# ...

# %%
df1.reset_index(drop=True, inplace=True)

# %%
df1
# Out:
#             date  category_id  category  \
# 0     2020-01-01            0   opinion
# 1     2020-01-01            1     world
# 2     2020-01-01            1     world
# 3     2020-01-01            2  politics
# 4     2020-01-01            3      arts
# ...          ...          ...       ...
# 2343  2020-01-31            4  business
# 2344  2020-01-31            2  politics
# 2345  2020-01-31            5    sports
# 2346  2020-01-31            5    sports
# 2347  2020-01-31            2  politics
#
#                                                headline  \
# 0                           Protect Veterans From Fraud
# 1     Hospitals and Schools Are Being Bombed in Syri...
# 2     Hong Kong Protesters Return to Streets as New ...
# 3       Dizzying Day for Trump Caps a Year Full of Them
# 4     What’s on TV Wednesday: A Linda Ronstadt Doc a...
# ...                                                 ...
# 2343  Richard Plepler and Josh Tyrangiel May Revive ...
# ...

# %%
df1[['category_id', 'category']].drop_duplicates().sort_values('category_id')
# Out:
#     category_id  category
# 0             0   opinion
# 1             1     world
# 3             2  politics
# 4             3      arts
# 6             4  business
# 19            5    sports

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2348 entries, 0 to 2347
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         2348 non-null   object
#  1   category_id  2348 non-null   int64
#  2   category     2348 non-null   object
#  3   headline     2348 non-null   object
#  4   articles     2341 non-null   object
#  5   url          2348 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 110.2+ KB

# %%
df1['check'] = df1['articles'].isnull()

# %%
df1.loc[df1['check'] == True]
# Out:
#             date  category_id  category  \
# 111   2020-01-03            0   opinion
# 202   2020-01-04            5    sports
# 235   2020-01-05            4  business
# 339   2020-01-07            5    sports
# 703   2020-01-12            4  business
# 1814  2020-01-26            4  business
# 2071  2020-01-29            2  politics
#
#                                                headline articles  \
# 111                                             Privacy      NaN
# 202                        How to Buy? Say You’ll Sell.      NaN
# 235   The Week in Business: A Former Auto Titan’s Sh...      NaN
# 339   How Cassius Winston Greets His Late Brother Be...      NaN
# 703   The Week in Business: Flying Ubers and Pricey ...      NaN
# 1814  The Week in Business: Beware Mysterious Videos...      NaN
# 2071             On Politics: Biden Seizes on a Comment      NaN
#
#                                                     url  check
# ...

# %%
df1
# Out:
#             date  category_id  category  \
# 0     2020-01-01            0   opinion
# 1     2020-01-01            1     world
# 2     2020-01-01            1     world
# 3     2020-01-01            2  politics
# 4     2020-01-01            3      arts
# ...          ...          ...       ...
# 2343  2020-01-31            4  business
# 2344  2020-01-31            2  politics
# 2345  2020-01-31            5    sports
# 2346  2020-01-31            5    sports
# 2347  2020-01-31            2  politics
#
#                                                headline  \
# 0                           Protect Veterans From Fraud
# 1     Hospitals and Schools Are Being Bombed in Syri...
# 2     Hong Kong Protesters Return to Streets as New ...
# 3       Dizzying Day for Trump Caps a Year Full of Them
# 4     What’s on TV Wednesday: A Linda Ronstadt Doc a...
# ...                                                 ...
# 2343  Richard Plepler and Josh Tyrangiel May Revive ...
# ...

# %%
index_name = df1[df1['check'] == True].index

# %%
df1.drop(index_name, inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2341 entries, 0 to 2347
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         2341 non-null   object
#  1   category_id  2341 non-null   int64
#  2   category     2341 non-null   object
#  3   headline     2341 non-null   object
#  4   articles     2341 non-null   object
#  5   url          2341 non-null   object
#  6   check        2341 non-null   bool
# dtypes: bool(1), int64(1), object(5)
# memory usage: 130.3+ KB

# %%
df1.reset_index(drop=True, inplace=True)

# %%
df1['date'] = pd.to_datetime(df1['date'])

# %%
df1
# Out:
#            date  category_id  category  \
# 0    2020-01-01            0   opinion
# 1    2020-01-01            1     world
# 2    2020-01-01            1     world
# 3    2020-01-01            2  politics
# 4    2020-01-01            3      arts
# ...         ...          ...       ...
# 2336 2020-01-31            4  business
# 2337 2020-01-31            2  politics
# 2338 2020-01-31            5    sports
# 2339 2020-01-31            5    sports
# 2340 2020-01-31            2  politics
#
#                                                headline  \
# 0                           Protect Veterans From Fraud
# 1     Hospitals and Schools Are Being Bombed in Syri...
# 2     Hong Kong Protesters Return to Streets as New ...
# 3       Dizzying Day for Trump Caps a Year Full of Them
# 4     What’s on TV Wednesday: A Linda Ronstadt Doc a...
# ...                                                 ...
# 2336  Richard Plepler and Josh Tyrangiel May Revive ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2341 entries, 0 to 2340
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         2341 non-null   datetime64[ns]
#  1   category_id  2341 non-null   int64
#  2   category     2341 non-null   object
#  3   headline     2341 non-null   object
#  4   articles     2341 non-null   object
#  5   url          2341 non-null   object
#  6   check        2341 non-null   bool
# dtypes: bool(1), datetime64[ns](1), int64(1), object(4)
# memory usage: 112.1+ KB

# %%
df1.drop(['check'], axis='columns', inplace=True)

# %%
df1['articles'] = df1['articles'].str.replace('[^\w\s]','')
# Out:
# C:\Users\Marwan\AppData\Local\Temp/ipykernel_4432/4226504336.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['articles'] = df1['articles'].str.replace('[^\w\s]','')

# %%
df1
# Out:
#            date  category_id  category  \
# 0    2020-01-01            0   opinion
# 1    2020-01-01            1     world
# 2    2020-01-01            1     world
# 3    2020-01-01            2  politics
# 4    2020-01-01            3      arts
# ...         ...          ...       ...
# 2336 2020-01-31            4  business
# 2337 2020-01-31            2  politics
# 2338 2020-01-31            5    sports
# 2339 2020-01-31            5    sports
# 2340 2020-01-31            2  politics
#
#                                                headline  \
# 0                           Protect Veterans From Fraud
# 1     Hospitals and Schools Are Being Bombed in Syri...
# 2     Hong Kong Protesters Return to Streets as New ...
# 3       Dizzying Day for Trump Caps a Year Full of Them
# 4     What’s on TV Wednesday: A Linda Ronstadt Doc a...
# ...                                                 ...
# 2336  Richard Plepler and Josh Tyrangiel May Revive ...
# ...

# %%
def remove_tags(text):
  remove = re.compile(r'')
  return re.sub(remove, '', text)

# %%
def convert_lower(text):
   return text.lower()

# %%
df1['articles'] = df1['articles'].apply(convert_lower)

# %%
df1['articles'] = df1['articles'].apply(remove_tags)

# %%
df1
# Out:
#            date  category_id  category  \
# 0    2020-01-01            0   opinion
# 1    2020-01-01            1     world
# 2    2020-01-01            1     world
# 3    2020-01-01            2  politics
# 4    2020-01-01            3      arts
# ...         ...          ...       ...
# 2336 2020-01-31            4  business
# 2337 2020-01-31            2  politics
# 2338 2020-01-31            5    sports
# 2339 2020-01-31            5    sports
# 2340 2020-01-31            2  politics
#
#                                                headline  \
# 0                           Protect Veterans From Fraud
# 1     Hospitals and Schools Are Being Bombed in Syri...
# 2     Hong Kong Protesters Return to Streets as New ...
# 3       Dizzying Day for Trump Caps a Year Full of Them
# 4     What’s on TV Wednesday: A Linda Ronstadt Doc a...
# ...                                                 ...
# 2336  Richard Plepler and Josh Tyrangiel May Revive ...
# ...

# %%
df1['articles'] = df1['articles'].str.strip()

# %%
df1
# Out:
#            date  category_id  category  \
# 0    2020-01-01            0   opinion
# 1    2020-01-01            1     world
# 2    2020-01-01            1     world
# 3    2020-01-01            2  politics
# 4    2020-01-01            3      arts
# ...         ...          ...       ...
# 2336 2020-01-31            4  business
# 2337 2020-01-31            2  politics
# 2338 2020-01-31            5    sports
# 2339 2020-01-31            5    sports
# 2340 2020-01-31            2  politics
#
#                                                headline  \
# 0                           Protect Veterans From Fraud
# 1     Hospitals and Schools Are Being Bombed in Syri...
# 2     Hong Kong Protesters Return to Streets as New ...
# 3       Dizzying Day for Trump Caps a Year Full of Them
# 4     What’s on TV Wednesday: A Linda Ronstadt Doc a...
# ...                                                 ...
# 2336  Richard Plepler and Josh Tyrangiel May Revive ...
# ...

# %%
df1['articles']
# Out:
# 0       congress could do much more to protect america...
# 1       attacks on civilian sites in syria have grown ...
# 2       weeks of relative calm ended on wednesday as p...
# 3       the president monitored a middle east crisis f...
# 4       linda ronstadt the sound of my voice airs on c...
#                               ...
# 2336    the former boss of the premium cable network i...
# 2337    in the lobby of the presidents washington hote...
# 2338    it was the lakers first game since bryant and ...
# 2339    the famed running coach was already barred fro...
# 2340    senators rejected a call for additional witnes...
# Name: articles, Length: 2341, dtype: object

# %%
df1.to_csv('../data/cleaned/cleaned-data.csv', index=None)
