# %% [markdown]
# ปัญหาที่พบเจอ
# - คอลลัมพ์ Keywords เป็น list ที่แยกกัน

# %%
import pandas as pd

# %% [markdown]
# #### import Data

# %%
df = pd.read_csv('../data/raw/raw-data.csv')
label = pd.read_csv('../data/cleaned/label 2020.01.csv')

# %%
# %store df
# Out:
# Stored 'df' (DataFrame)

# %% [markdown]
# Store to work with EDA

# %%
df['label'] = label

# %%
df = df[['date', 'label', 'headline', 'snippet',  'url']]

# %%
df
# Out:
#             date       label  \
# 0     2020-01-01          us
# 1     2020-01-01     opinion
# 2     2020-01-01      health
# 3     2020-01-01  crosswords
# 4     2020-01-01          us
# ...          ...         ...
# 4475  2020-01-31      sports
# 4476  2020-01-31      sports
# 4477  2020-01-31      health
# 4478  2020-01-31    politics
# 4479  2020-01-31    nyregion
#
#                                                headline  \
# 0     ‘Battling a Demon’: Drifter Sought Help Before...
# 1                           Protect Veterans From Fraud
# 2     F.D.A. Plans to Ban Most E-Cigarette Flavors b...
# 3                                ‘It’s Green and Slimy’
# 4                             Corrections: Jan. 1, 2020
# ...                                                 ...
# 4475  Lakers Fall to Blazers on Emotional Night Hono...
# 4476  Alberto Salazar Is Suspended by SafeSport Afte...
# 4477                                    CPR, by Default
# ...

# %% [markdown]
# #### Drop Column

# %%
df = df[df.label != ('us','well','todayspaper', 'crosswords','podcasts','reader-center', 'magazine')]

# %%
df
# Out:
#             date       label  \
# 0     2020-01-01          us
# 1     2020-01-01     opinion
# 2     2020-01-01      health
# 3     2020-01-01  crosswords
# 4     2020-01-01          us
# ...          ...         ...
# 4475  2020-01-31      sports
# 4476  2020-01-31      sports
# 4477  2020-01-31      health
# 4478  2020-01-31    politics
# 4479  2020-01-31    nyregion
#
#                                                headline  \
# 0     ‘Battling a Demon’: Drifter Sought Help Before...
# 1                           Protect Veterans From Fraud
# 2     F.D.A. Plans to Ban Most E-Cigarette Flavors b...
# 3                                ‘It’s Green and Slimy’
# 4                             Corrections: Jan. 1, 2020
# ...                                                 ...
# 4475  Lakers Fall to Blazers on Emotional Night Hono...
# 4476  Alberto Salazar Is Suspended by SafeSport Afte...
# 4477                                    CPR, by Default
# ...

# %%
df.to_csv('../data/cleaned/cleaned-data.csv', index=None)
