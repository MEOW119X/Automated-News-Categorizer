# %% [markdown]
# ปัญหาที่พบเจอ
# - คอลลัมพ์ Keywords เป็น list ที่แยกกัน

# %%
import pandas as pd
import re

# %% [markdown]
# ## import Data
# #### import data from raw data that's queried by API

# %%
df = pd.read_csv('../data/raw/raw-data.csv')

# %%
df
# Out:
#             date                                                url  \
# 0     2020-01-01  https://www.nytimes.com/2019/12/31/us/texas-ch...
# 1     2020-01-01  https://www.nytimes.com/2019/12/31/opinion/for...
# 2     2020-01-01  https://www.nytimes.com/2019/12/31/health/e-ci...
# 3     2020-01-01  https://www.nytimes.com/2019/12/31/crosswords/...
# 4     2020-01-01  https://www.nytimes.com/2019/12/31/pageoneplus...
# ...          ...                                                ...
# 4475  2020-01-31  https://www.nytimes.com/2020/01/31/sports/bask...
# 4476  2020-01-31  https://www.nytimes.com/2020/01/31/sports/olym...
# 4477  2020-01-31  https://www.nytimes.com/2020/01/31/health/cpr-...
# 4478  2020-01-31  https://www.nytimes.com/video/us/politics/1000...
# 4479  2020-01-31  https://www.nytimes.com/2020/01/31/nyregion/pr...
#
#                                                headline  \
# 0     ‘Battling a Demon’: Drifter Sought Help Before...
# ...

# %%
df.shape
# Out:
# (4480, 9)

# %% [markdown]
# ## Checking all lebels and it's number

# %%
def count_values(dataframe ,a):
    '''function is for counting the total numbers of the specific lebel'''
    
    label = []
    u_names = []
    count = []
    for i in dataframe[a]:
        label.append(i)
    for names in label:
        if names not in u_names:
            names = str(names)
            u_names.append(names)
    for num in u_names:
        count.append(label.count(num))
    return pd.DataFrame({'Label': u_names, 'Numbers': count})

# %%
count_values(df ,'label')
# Out:
#               Label  Numbers
# 0                us      287
# 1           opinion      503
# 2            health       49
# 3        crosswords       43
# 4       todayspaper       28
# 5             world      482
# 6          politics      494
# 7           science       61
# 8              arts      346
# 9          business      297
# 10         magazine       67
# 11            books      173
# 12             well       56
# 13           travel       41
# 14       technology       59
# 15         nyregion      189
# 16           movies      134
# 17       realestate      109
# 18           sports      226
# 19          theater       64
# 20           dining      104
# 21            style      133
# 22        parenting        6
# 23         briefing      100
# 24          climate       27
# 25   smarter-living       16
# 26       obituaries       13
# 27         learning      115
# 28    reader-center       23
# 29         podcasts       30
# 30       t-magazine       26
# ...

# %% [markdown]
# ## Select data
# #### Create new dataframe and select only wanted cloumns

# %%
df1 = df[['date','label', 'headline', 'articles', 'url']]

# %%
df1
# Out:
#             date       label  \
# 0     2020-01-01          us
# 1     2020-01-01     opinion
# 2     2020-01-01      health
# 3     2020-01-01  crosswords
# 4     2020-01-01          us
# ...          ...         ...
# 4475  2020-01-31      sports
# 4476  2020-01-31      sports
# 4477  2020-01-31      health
# 4478  2020-01-31    politics
# 4479  2020-01-31    nyregion
#
#                                                headline  \
# 0     ‘Battling a Demon’: Drifter Sought Help Before...
# 1                           Protect Veterans From Fraud
# 2     F.D.A. Plans to Ban Most E-Cigarette Flavors b...
# 3                                ‘It’s Green and Slimy’
# 4                             Corrections: Jan. 1, 2020
# ...                                                 ...
# 4475  Lakers Fall to Blazers on Emotional Night Hono...
# 4476  Alberto Salazar Is Suspended by SafeSport Afte...
# 4477                                    CPR, by Default
# ...

# %% [markdown]
# #### Select labels => sport, opinion, world, politics, business, arts and return it as a new column

# %%
df1 = df1.loc[df['label'].isin(['sports','opinion','world','politics','business','arts'])]

# %%
df1
# Out:
#             date     label                                           headline  \
# 1     2020-01-01   opinion                        Protect Veterans From Fraud
# 6     2020-01-01     world  Hospitals and Schools Are Being Bombed in Syri...
# 7     2020-01-01     world  Hong Kong Protesters Return to Streets as New ...
# 9     2020-01-01  politics    Dizzying Day for Trump Caps a Year Full of Them
# 13    2020-01-01      arts  What’s on TV Wednesday: A Linda Ronstadt Doc a...
# ...          ...       ...                                                ...
# 4473  2020-01-31  business  Richard Plepler and Josh Tyrangiel May Revive ...
# 4474  2020-01-31  politics      Trump Hotel Patrons Relish Impeachment Finale
# 4475  2020-01-31    sports  Lakers Fall to Blazers on Emotional Night Hono...
# 4476  2020-01-31    sports  Alberto Salazar Is Suspended by SafeSport Afte...
# 4478  2020-01-31  politics  Impeachment Trial Highlights: A Showdown Over ...
#
# ...

# %%
df1.shape
# Out:
# (2348, 5)

# %%
count_values(df1 ,'label')
# Out:
#       Label  Numbers
# 0   opinion      503
# 1     world      482
# 2  politics      494
# 3      arts      346
# 4  business      297
# 5    sports      226

# %% [markdown]
# ---------------------------------------------------------

# %% [markdown]
# #### Create category id for each seleted label

# %%
df2 = df1.copy(deep=True)

# %%
df2['category_id'] = df2['label'].factorize(sort=False)[0]

# %%
df2[['label','category_id']].drop_duplicates().sort_values('category_id')
# Out:
#        label  category_id
# 1    opinion            0
# 6      world            1
# 9   politics            2
# 13      arts            3
# 15  business            4
# 49    sports            5

# %%
df2 = df2[['date', 'category_id', 'label', 'headline', 'articles', 'url']]

# %%
df2
# Out:
#             date  category_id     label  \
# 1     2020-01-01            0   opinion
# 6     2020-01-01            1     world
# 7     2020-01-01            1     world
# 9     2020-01-01            2  politics
# 13    2020-01-01            3      arts
# ...          ...          ...       ...
# 4473  2020-01-31            4  business
# 4474  2020-01-31            2  politics
# 4475  2020-01-31            5    sports
# 4476  2020-01-31            5    sports
# 4478  2020-01-31            2  politics
#
#                                                headline  \
# 1                           Protect Veterans From Fraud
# 6     Hospitals and Schools Are Being Bombed in Syri...
# 7     Hong Kong Protesters Return to Streets as New ...
# 9       Dizzying Day for Trump Caps a Year Full of Them
# 13    What’s on TV Wednesday: A Linda Ronstadt Doc a...
# ...                                                 ...
# 4473  Richard Plepler and Josh Tyrangiel May Revive ...
# ...

# %%
df2 = df2.rename(index=str, columns = {"label" : "category"}, inplace=False)

# %%
df2
# Out:
#             date  category_id  category  \
# 1     2020-01-01            0   opinion
# 6     2020-01-01            1     world
# 7     2020-01-01            1     world
# 9     2020-01-01            2  politics
# 13    2020-01-01            3      arts
# ...          ...          ...       ...
# 4473  2020-01-31            4  business
# 4474  2020-01-31            2  politics
# 4475  2020-01-31            5    sports
# 4476  2020-01-31            5    sports
# 4478  2020-01-31            2  politics
#
#                                                headline  \
# 1                           Protect Veterans From Fraud
# 6     Hospitals and Schools Are Being Bombed in Syri...
# 7     Hong Kong Protesters Return to Streets as New ...
# 9       Dizzying Day for Trump Caps a Year Full of Them
# 13    What’s on TV Wednesday: A Linda Ronstadt Doc a...
# ...                                                 ...
# 4473  Richard Plepler and Josh Tyrangiel May Revive ...
# ...

# %%
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#             date  category_id  category  \
# 0     2020-01-01            0   opinion
# 1     2020-01-01            1     world
# 2     2020-01-01            1     world
# 3     2020-01-01            2  politics
# 4     2020-01-01            3      arts
# ...          ...          ...       ...
# 2343  2020-01-31            4  business
# 2344  2020-01-31            2  politics
# 2345  2020-01-31            5    sports
# 2346  2020-01-31            5    sports
# 2347  2020-01-31            2  politics
#
#                                                headline  \
# 0                           Protect Veterans From Fraud
# 1     Hospitals and Schools Are Being Bombed in Syri...
# 2     Hong Kong Protesters Return to Streets as New ...
# 3       Dizzying Day for Trump Caps a Year Full of Them
# 4     What’s on TV Wednesday: A Linda Ronstadt Doc a...
# ...                                                 ...
# 2343  Richard Plepler and Josh Tyrangiel May Revive ...
# ...

# %%
df2[['category_id', 'category']].drop_duplicates().sort_values('category_id')
# Out:
#     category_id  category
# 0             0   opinion
# 1             1     world
# 3             2  politics
# 4             3      arts
# 6             4  business
# 19            5    sports

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2348 entries, 1 to 4478
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      2348 non-null   object
#  1   label     2348 non-null   object
#  2   headline  2348 non-null   object
#  3   articles  2341 non-null   object
#  4   url       2348 non-null   object
# dtypes: object(5)
# memory usage: 110.1+ KB

# %%
class ClearNull:
    """Clear null values if null it will drop the rows out"""
    
    def __init__(self, dataframe, columns):
        self.dataframe = dataframe
        self.columns = columns
        
    def get_data(self):
        return self.dataframe[self.columns]
        
    def isnullchecking(self):
        df = self.get_data()
        self.dataframe['check'] = df.isnull()
        return self.dataframe[self.dataframe['check'] == True]
    
    def dropnull(self):
        null = self.isnullchecking()
        df = self.dataframe
        index_name = null[null['check'] == True].index
        df.drop(index_name, inplace=True)
        return self.dataframe
    
    def reset_index(self):
        df = self.dropnull()
        df.reset_index(drop=True, inplace=True)
        return df
    
    def drop_check(self):
        df = self.reset_index()
        df = df.drop(columns='check')
        return df
        
    def output(self):
        return self.drop_check()

# %%
dropnull = ClearNull(df2, 'articles')
dropnull = dropnull.output()

# %%
def show_drop_null(dropnull):
    dropnull = dropnull
    return dropnull

# %%
show_drop_null(dropnull)
# Out:
#             date  category_id  category  \
# 0     2020-01-01            0   opinion
# 1     2020-01-01            1     world
# 2     2020-01-01            1     world
# 3     2020-01-01            2  politics
# 4     2020-01-01            3      arts
# ...          ...          ...       ...
# 2336  2020-01-31            4  business
# 2337  2020-01-31            2  politics
# 2338  2020-01-31            5    sports
# 2339  2020-01-31            5    sports
# 2340  2020-01-31            2  politics
#
#                                                headline  \
# 0                           Protect Veterans From Fraud
# 1     Hospitals and Schools Are Being Bombed in Syri...
# 2     Hong Kong Protesters Return to Streets as New ...
# 3       Dizzying Day for Trump Caps a Year Full of Them
# 4     What’s on TV Wednesday: A Linda Ronstadt Doc a...
# ...                                                 ...
# 2336  Richard Plepler and Josh Tyrangiel May Revive ...
# ...

# %%
df2 = dropnull.copy(deep=True)

# %%
df2['date'] = pd.to_datetime(df2['date'])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2341 entries, 0 to 2340
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         2341 non-null   datetime64[ns]
#  1   category_id  2341 non-null   int64
#  2   category     2341 non-null   object
#  3   headline     2341 non-null   object
#  4   articles     2341 non-null   object
#  5   url          2341 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 109.9+ KB

# %%
df2
# Out:
#            date  category_id  category  \
# 0    2020-01-01            0   opinion
# 1    2020-01-01            1     world
# 2    2020-01-01            1     world
# 3    2020-01-01            2  politics
# 4    2020-01-01            3      arts
# ...         ...          ...       ...
# 2336 2020-01-31            4  business
# 2337 2020-01-31            2  politics
# 2338 2020-01-31            5    sports
# 2339 2020-01-31            5    sports
# 2340 2020-01-31            2  politics
#
#                                                headline  \
# 0                           Protect Veterans From Fraud
# 1     Hospitals and Schools Are Being Bombed in Syri...
# 2     Hong Kong Protesters Return to Streets as New ...
# 3       Dizzying Day for Trump Caps a Year Full of Them
# 4     What’s on TV Wednesday: A Linda Ronstadt Doc a...
# ...                                                 ...
# 2336  Richard Plepler and Josh Tyrangiel May Revive ...
# ...

# %% [markdown]
# ---------------------------------------------------

# %%
df3 = df2.copy(deep = True)

# %%
# %store df3
# Out:
# Stored 'df3' (DataFrame)

# %% [markdown]
# ## NLP

# %% [markdown]
# -------------------------------------------------------------------------------

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import stem
from nltk.stem import LancasterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import PorterStemmer
from nltk import pos_tag

# %%
nltk.download('punkt')
nltk.download('omw-1.4')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Marwan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Marwan\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Marwan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def devr(row):
    text =""
    row.lowercase()
    word_tokenize(row)
    stop_words = set(stopwords.words('english'))
    for i in row:
        if i.isalnum():
            if i not in stop_words:
                 text += i
        else:
            text += " "
    return text

# %%
def remove_special_char(row):
    '''Remove special characters from text
       if text is alphanumeric return as cchae
       if not return white space'''
    
    text = ""
    for character in row:
        if character.isalnum():
            text += character 
        else:
            text += ' '
    return text

# %%
def join_words(row):
    '''Join the words after tokenize'''
    
    return " ".join(text for text in row)

# %%
def lowerCase(row):
    '''Lower case the words'''
    
    return row.lower()

# %%
def word_tags(row):
    pos_tag(word_tokenize(row))

# %%
def words_tokenize(row):
    '''return tokens'''
    return word_tokenize(row)

# %%
def remove_stopwords(row):
    '''return '''  
    wordnet = WordNetLemmatizer()
    stop_words = set(stopwords.words('english'))
    return [wordnet.lemmatize(x) for x in row if x not in stop_words]

# %%
def join_words(row):
    '''Join the words after tokenize'''
    return " ".join(text for text in row)

# %%
df3['articles'] = df3['articles'].apply(remove_special_char)

# %%
df3['articles'] = df3['articles'].apply(words_tokenize)

# %%
df3['articles'] = df3['articles'].apply(remove_stopwords)

# %%
df3['articles'] = df3['articles'].apply(join_words)

# %%
df3['articles'] = df3['articles'].apply(lowerCase)

# %%
df3
# Out:
#            date  category_id  category  \
# 0    2020-01-01            0   opinion
# 1    2020-01-01            1     world
# 2    2020-01-01            1     world
# 3    2020-01-01            2  politics
# 4    2020-01-01            3      arts
# ...         ...          ...       ...
# 2336 2020-01-31            4  business
# 2337 2020-01-31            2  politics
# 2338 2020-01-31            5    sports
# 2339 2020-01-31            5    sports
# 2340 2020-01-31            2  politics
#
#                                                headline  \
# 0                           Protect Veterans From Fraud
# 1     Hospitals and Schools Are Being Bombed in Syri...
# 2     Hong Kong Protesters Return to Streets as New ...
# 3       Dizzying Day for Trump Caps a Year Full of Them
# 4     What’s on TV Wednesday: A Linda Ronstadt Doc a...
# ...                                                 ...
# 2336  Richard Plepler and Josh Tyrangiel May Revive ...
# ...

# %% [markdown]
# --------------------------------------------------

# %%
df4['articles'] = df4['articles'].apply(words_tokenize)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17944/3881342748.py in <module>
# ----> 1 df4['articles'] = df4['articles'].apply(words_tokenize)
#
# NameError: name 'df4' is not defined

# %%
df4['articles'] = df4['articles'].apply(words_tag)

# %%
df4

# %%
df4

# %%
for i, tag in df4['articles']:
    print(tag)

# %%
def word_tags(row):
    for i, tag in row.values:
        if tag.startswith('V'):
            return lemmatizer.lemmatize(i, pos="v")
        elif tag.startswith('P'):
            return lemmatizer.lemmatize(i,pos="n")
        elif tag.startswith('R'):
            return lemmatizer.lemmatize(i, pos="r")
        elif tag.startswith('J'):
            return lemmatizer.lemmatize(i, pos="a")

# %%
j= word_tokenize('i am your father')

# %%
k = pos_tag(j)

# %%
word_tags(k)

# %%
def oo():
    for i in k:
        return i

# %%
oo()

# %%
if I make my mistake I personally want to make bad

# %%
result = [(1,2),(1,4)]

# %%
row = [item[0] for item in result]

# %%
def lemmi(row):
    for i in row:
        if i[1].startswith('V'):
            return lemmatizer.lemmatize(i, pos="v")
        elif i[1].startswith('P'):
            return lemmatizer.lemmatize(i,pos="n")
        elif i[1].startswith('R'):
            return lemmatizer.lemmatize(i, pos="r")
        elif i[1].startswith('J'):
            return lemmatizer.lemmatize(i, pos="a")

# %%
def words_lemmatizer(row):
    for i, tag in row:
            if tag.startswith('V'):
                return lemmatizer.lemmatize(i, pos="v")
            elif tag.startswith('P'):
                return lemmatizer.lemmatize(i,pos="n")
            elif tag.startswith('R'):
                return lemmatizer.lemmatize(i, pos="r")
            elif tag.startswith('J'):
                return lemmatizer.lemmatize(i, pos="a")
            else:
                return " "

# %%
df4

# %%
hellopp = "I want to fuck you up"

# %%
klp = word_tokenize(hellopp)

# %%
type(klp)

# %%
stop_words = set(stopwords.words('english'))

# %%
type(stop_words)

# %%
jaja = "hello my friend i am from a word"

# %%
jaja = words_tokenize(jaja)

# %%
for i in jaja:
    if i not in stop_words:
        print(i, end=" ")

# %%
stop_words

# %%
he = "He is my friends"

# %%
he.lower()
