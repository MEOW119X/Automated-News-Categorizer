# %%
import requests

# %%
url = requests.get('https://api.nytimes.com/svc/news/v3/content/all/all.json?api-key=hZpfTt35C1OK7ibsJn8Ti1IXOzHCb0HU')
json_data = url.json()

# %%
json_data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2022 The New York Times Company.  All Rights Reserved.',
#  'num_results': 500,
#  'results': [{'slug_name': '17artoftheater-review',
#    'section': 'Theater',
#    'subsection': '',
#    'title': 'In a Double Bill, the Avant-Garde Meets a Very Good Girl',
#    'abstract': 'Excellent performances, including one by a well-behaved dog, warm up two experimental plays upstate.',
#    'uri': 'nyt://article/5bf1cfa4-9cc8-58c1-9214-5cf292e8fe09',
#    'url': 'https://www.nytimes.com/2022/01/17/theater/art-of-theater-with-my-own-hands-ps21.html',
#    'byline': 'BY JESSE GREEN',
#    'thumbnail_standard': 'https://static01.nyt.com/images/2022/01/17/arts/17ARTOFTHEATER1/17ARTOFTHEATER1-thumbStandard.jpg',
#    'item_type': 'Article',
#    'source': 'New York Times',
#    'updated_date': '2022-01-17T13:30:39-05:00',
#    'created_date': '2022-01-17T13:30:39-05:00',
#    'published_date': '2022-01-17T13:30:39-05:00',
# ...
