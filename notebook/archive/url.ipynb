# %%
import pandas as pb

# %%
url = pb.read_csv('../../data/raw/url.csv')
df = pb.read_csv('../../data/raw/raw-data.csv')

# %%
df
# Out:
#       Unnamed: 0        date        label  \
# 0              0  2020-01-01           us
# 1              1  2020-01-01      opinion
# 2              2  2020-01-01       health
# 3              3  2020-01-01   crosswords
# 4              4  2020-01-01  pageoneplus
# ...          ...         ...          ...
# 4475        4475  2020-01-31       sports
# 4476        4476  2020-01-31       sports
# 4477        4477  2020-01-31       health
# 4478        4478  2020-01-31           us
# 4479        4479  2020-01-31     nyregion
#
#                                                headline  \
# 0     ‘Battling a Demon’: Drifter Sought Help Before...
# 1                           Protect Veterans From Fraud
# 2     F.D.A. Plans to Ban Most E-Cigarette Flavors b...
# 3                                ‘It’s Green and Slimy’
# 4                             Corrections: Jan. 1, 2020
# ...                                                 ...
# 4475  Lakers Fall to Blazers on Emotional Night Hono...
# ...

# %%
for i in df

# %%
politics=[]

# %%
df.loc[df['url']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16400/814288611.py in <module>
# ----> 1 df.loc[df['url'].find('us/politics')]
#
# D:\Project\finalproject\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'find'
