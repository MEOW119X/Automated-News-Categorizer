# %%
import pandas as pd

# %%
df = pd.read_csv('../data/cleaned/cleaned-data.csv')

# %%
from nltk import word_tokenize
import nltk
from nltk import WordNetLemmatizer

# %%
class ClearNull:
    """Clear null values if null it will drop the rows out"""
    
    def __init__(self, dataframe, columns):
        self.dataframe = dataframe
        self.columns = columns
        
    def get_data(self):
        return self.dataframe[self.columns]
        
    def isnullchecking(self):
        """Check if the text is null or not if null turn into True"""
        df = self.get_data()
        self.dataframe['check'] = df.isnull()
        return self.dataframe[self.dataframe['check'] == True]
    
    def dropnull(self):
        """Drop the null row"""
        null = self.isnullchecking()
        df = self.dataframe
        index_name = null[null['check'] == True].index
        df.drop(index_name, inplace=True)
        return self.dataframe
    
    def reset_index(self):
        """Reset the index of the row"""
        df = self.dropnull()
        df.reset_index(drop=True, inplace=True)
        return df
    
    def drop_check(self):
        df = self.reset_index()
        df = df.drop(columns='check')
        return df
        
    def output(self):
        return self.drop_check()

# %%
dropnull = ClearNull(df, 'articles')
dropnull = dropnull.output()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2341 entries, 0 to 2340
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         2341 non-null   object
#  1   category_id  2341 non-null   int64
#  2   category     2341 non-null   object
#  3   headline     2341 non-null   object
#  4   articles     2341 non-null   object
#  5   url          2341 non-null   object
#  6   check        2341 non-null   bool
# dtypes: bool(1), int64(1), object(5)
# memory usage: 112.1+ KB

# %%
def words_lemmatize(row):
    """lemmatize the text with pos_tag"""
    lemmatizer = WordNetLemmatizer()  
    return [lemmatizer.lemmatize(x, 'v') if i.startswith('V') else lemmatizer.lemmatize(x, 'n') if i.startswith('N') else lemmatizer.lemmatize(x, 'a') if i.startswith('J') else lemmatizer.lemmatize(x, 'r') if i.startswith('R') else '' for x,i in row]

# %%
df.articles = df.articles.apply(lambda x: x.lower())
df.articles = df.articles.apply(lambda x: word_tokenize(x))
df.articles = df.articles.apply(lambda x: nltk.pos_tag(x))
df.articles = df.articles.apply(words_lemmatize)

# %%
df
# Out:
#             date  category_id  category  \
# 0     2020-01-01            0   opinion
# 1     2020-01-01            1     world
# 2     2020-01-01            1     world
# 3     2020-01-01            2  politics
# 4     2020-01-01            3      arts
# ...          ...          ...       ...
# 2336  2020-01-31            4  business
# 2337  2020-01-31            2  politics
# 2338  2020-01-31            5    sports
# 2339  2020-01-31            5    sports
# 2340  2020-01-31            2  politics
#
#                                                headline  \
# 0                           Protect Veterans From Fraud
# 1     Hospitals and Schools Are Being Bombed in Syri...
# 2     Hong Kong Protesters Return to Streets as New ...
# 3       Dizzying Day for Trump Caps a Year Full of Them
# 4     What’s on TV Wednesday: A Linda Ronstadt Doc a...
# ...                                                 ...
# 2336  Richard Plepler and Josh Tyrangiel May Revive ...
# 2337      Trump Hotel Patrons Relish Impeachment Finale
# 2338  Lakers Fall to Blazers on Emotional Night Hono...
# 2339  Alberto Salazar Is Suspended by SafeSport Afte...
# 2340  Impeachment Trial Highlights: A Showdown Over ...
#
#                                                articles  \
# 0     [congress, , do, much, more, , protect, americ...
# 1     [attack, , civilian, site, , syria, have, grow...
# 2     [week, , relative, calm, end, , wednesday, , ,...
# 3     [, president, monitor, , middle, east, crisis,...
# 4     [“, linda, ronstadt, , , sound, , , voice, ”, ...
# ...                                                 ...
# 2336  [, former, bos, , , premium, cable, network, b...
# 2337  [, , lobby, , , president, ’, s, washington, h...
# 2338  [, be, , lakers, ’, first, game, , bryant, , ,...
# 2339  [, famed, running, coach, be, already, bar, , ...
# 2340  [senator, reject, , call, , additional, witnes...
#
#                                                     url  check
# 0     https://www.nytimes.com/2019/12/31/opinion/for...  False
# 1     https://www.nytimes.com/interactive/2019/12/31...  False
# 2     https://www.nytimes.com/2020/01/01/world/asia/...  False
# 3     https://www.nytimes.com/2019/12/31/us/politics...  False
# 4     https://www.nytimes.com/2020/01/01/arts/televi...  False
# ...                                                 ...    ...
# 2336  https://www.nytimes.com/2020/01/31/business/me...  False
# 2337  https://www.nytimes.com/2020/01/31/us/politics...  False
# 2338  https://www.nytimes.com/2020/01/31/sports/bask...  False
# 2339  https://www.nytimes.com/2020/01/31/sports/olym...  False
# 2340  https://www.nytimes.com/video/us/politics/1000...  False
#
# [2341 rows x 7 columns]

# %%
nltk.pos_tag(["running"])
# Out:
# [('running', 'VBG')]
