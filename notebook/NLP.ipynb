# %%
# %store -r df3

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
stops = set(stopwords.words('english'))
print(stops)
# Out:
# {"mustn't", 'weren', "that'll", 'when', 'me', 'both', 'couldn', 'this', 'shan', 'of', 'because', 'hers', 'few', 'she', 'only', 's', "won't", 't', 'below', 'most', 'ma', 'them', 'who', 'has', 'o', 'too', "needn't", 'at', 'yourself', 'above', 'myself', 'had', "hadn't", "don't", 'won', 'in', 'doing', 'through', 'by', "should've", 'each', "you'd", 'were', 'should', 'against', 'theirs', 'his', 'where', 'about', "aren't", "doesn't", 'our', "wasn't", 'an', "wouldn't", 'd', 'having', 'my', 'ours', 'just', 'y', 'ain', 'herself', 'before', "didn't", "you've", "you'll", 'themselves', "shan't", 'into', 'on', 'and', "weren't", 'those', 'he', 'again', 'same', 'am', 'between', "mightn't", 'or', 'don', 'doesn', 'hasn', "she's", 'is', 'hadn', 'further', 'what', 'a', 'your', 'why', 'itself', 'you', 'but', 'down', 'being', 'up', 'wouldn', 'himself', 'it', 'i', 'its', 'now', 'over', 'aren', 'from', 'did', 'all', 'than', 'was', 'once', 'other', 'for', 'will', 'her', 'shouldn', 'needn', 'under', 'during', 'with', 'very', 'after', "haven't", 'such', 'so', 'no', 'yours', "it's", 'while', 'there', 'isn', 'have', 'nor', 'not', 'been', 'that', 'll', 'ourselves', 'yourselves', 'own', 've', 'these', 'if', 'are', 'off', 'whom', "isn't", 'haven', 'their', 'some', 'we', "you're", 'him', "hasn't", 'more', 'do', 'how', 'out', 'didn', 'be', 'which', "couldn't", 'they', 'the', 'until', 'mightn', 'any', "shouldn't", 'to', 'here', 'm', 'wasn', 'as', 'mustn', 're', 'can', 'then', 'does'}

# %%
df3
# Out:
#            date  category_id  category  \
# 0    2020-01-01            0   opinion
# 1    2020-01-01            1     world
# 2    2020-01-01            1     world
# 3    2020-01-01            2  politics
# 4    2020-01-01            3      arts
# ...         ...          ...       ...
# 2336 2020-01-31            4  business
# 2337 2020-01-31            2  politics
# 2338 2020-01-31            5    sports
# 2339 2020-01-31            5    sports
# 2340 2020-01-31            2  politics
#
#                                                headline  \
# 0                           Protect Veterans From Fraud
# 1     Hospitals and Schools Are Being Bombed in Syri...
# 2     Hong Kong Protesters Return to Streets as New ...
# 3       Dizzying Day for Trump Caps a Year Full of Them
# 4     What’s on TV Wednesday: A Linda Ronstadt Doc a...
# ...                                                 ...
# 2336  Richard Plepler and Josh Tyrangiel May Revive ...
# 2337      Trump Hotel Patrons Relish Impeachment Finale
# 2338  Lakers Fall to Blazers on Emotional Night Hono...
# 2339  Alberto Salazar Is Suspended by SafeSport Afte...
# 2340  Impeachment Trial Highlights: A Showdown Over ...
#
#                                                articles  \
# 0     Congress could do much more to protect America...
# 1     Attacks on civilian sites in Syria have grown ...
# 2     Weeks of relative calm ended on Wednesday, as ...
# 3     The president monitored a Middle East crisis f...
# 4     “Linda Ronstadt: The Sound of My Voice” airs o...
# ...                                                 ...
# 2336  The former boss of the premium cable network i...
# 2337  In the lobby of the president’s Washington hot...
# 2338  It was the Lakers’ first game since Bryant and...
# 2339  The famed running coach was already barred fro...
# 2340  Senators rejected a call for additional witnes...
#
#                                                     url  \
# 0     https://www.nytimes.com/2019/12/31/opinion/for...
# 1     https://www.nytimes.com/interactive/2019/12/31...
# 2     https://www.nytimes.com/2020/01/01/world/asia/...
# 3     https://www.nytimes.com/2019/12/31/us/politics...
# 4     https://www.nytimes.com/2020/01/01/arts/televi...
# ...                                                 ...
# 2336  https://www.nytimes.com/2020/01/31/business/me...
# 2337  https://www.nytimes.com/2020/01/31/us/politics...
# 2338  https://www.nytimes.com/2020/01/31/sports/bask...
# 2339  https://www.nytimes.com/2020/01/31/sports/olym...
# 2340  https://www.nytimes.com/video/us/politics/1000...
#
#                                         tokenized_sents
# 0     [Congress, could, do, much, more, to, protect,...
# 1     [Attacks, on, civilian, sites, in, Syria, have...
# 2     [Weeks, of, relative, calm, ended, on, Wednesd...
# 3     [The, president, monitored, a, Middle, East, c...
# 4     [“, Linda, Ronstadt, :, The, Sound, of, My, Vo...
# ...                                                 ...
# 2336  [The, former, boss, of, the, premium, cable, n...
# 2337  [In, the, lobby, of, the, president, ’, s, Was...
# 2338  [It, was, the, Lakers, ’, first, game, since, ...
# 2339  [The, famed, running, coach, was, already, bar...
# 2340  [Senators, rejected, a, call, for, additional,...
#
# [2341 rows x 7 columns]

# %%
# TODO : Add apply function

# %%
df3['tokenized_sents'] = df3['articles'].apply(lambda row: nltk.word_tokenize(row))

# %%
df3
# Out:
#            date  category_id  category  \
# 0    2020-01-01            0   opinion
# 1    2020-01-01            1     world
# 2    2020-01-01            1     world
# 3    2020-01-01            2  politics
# 4    2020-01-01            3      arts
# ...         ...          ...       ...
# 2336 2020-01-31            4  business
# 2337 2020-01-31            2  politics
# 2338 2020-01-31            5    sports
# 2339 2020-01-31            5    sports
# 2340 2020-01-31            2  politics
#
#                                                headline  \
# 0                           Protect Veterans From Fraud
# 1     Hospitals and Schools Are Being Bombed in Syri...
# 2     Hong Kong Protesters Return to Streets as New ...
# 3       Dizzying Day for Trump Caps a Year Full of Them
# 4     What’s on TV Wednesday: A Linda Ronstadt Doc a...
# ...                                                 ...
# 2336  Richard Plepler and Josh Tyrangiel May Revive ...
# 2337      Trump Hotel Patrons Relish Impeachment Finale
# 2338  Lakers Fall to Blazers on Emotional Night Hono...
# 2339  Alberto Salazar Is Suspended by SafeSport Afte...
# 2340  Impeachment Trial Highlights: A Showdown Over ...
#
#                                                articles  \
# 0     Congress could do much more to protect America...
# 1     Attacks on civilian sites in Syria have grown ...
# 2     Weeks of relative calm ended on Wednesday, as ...
# 3     The president monitored a Middle East crisis f...
# 4     “Linda Ronstadt: The Sound of My Voice” airs o...
# ...                                                 ...
# 2336  The former boss of the premium cable network i...
# 2337  In the lobby of the president’s Washington hot...
# 2338  It was the Lakers’ first game since Bryant and...
# 2339  The famed running coach was already barred fro...
# 2340  Senators rejected a call for additional witnes...
#
#                                                     url  \
# 0     https://www.nytimes.com/2019/12/31/opinion/for...
# 1     https://www.nytimes.com/interactive/2019/12/31...
# 2     https://www.nytimes.com/2020/01/01/world/asia/...
# 3     https://www.nytimes.com/2019/12/31/us/politics...
# 4     https://www.nytimes.com/2020/01/01/arts/televi...
# ...                                                 ...
# 2336  https://www.nytimes.com/2020/01/31/business/me...
# 2337  https://www.nytimes.com/2020/01/31/us/politics...
# 2338  https://www.nytimes.com/2020/01/31/sports/bask...
# 2339  https://www.nytimes.com/2020/01/31/sports/olym...
# 2340  https://www.nytimes.com/video/us/politics/1000...
#
#                                         tokenized_sents
# 0     [Congress, could, do, much, more, to, protect,...
# 1     [Attacks, on, civilian, sites, in, Syria, have...
# 2     [Weeks, of, relative, calm, ended, on, Wednesd...
# 3     [The, president, monitored, a, Middle, East, c...
# 4     [“, Linda, Ronstadt, :, The, Sound, of, My, Vo...
# ...                                                 ...
# 2336  [The, former, boss, of, the, premium, cable, n...
# 2337  [In, the, lobby, of, the, president, ’, s, Was...
# 2338  [It, was, the, Lakers, ’, first, game, since, ...
# 2339  [The, famed, running, coach, was, already, bar...
# 2340  [Senators, rejected, a, call, for, additional,...
#
# [2341 rows x 7 columns]

# %%
data = "All work and no play makes jack dull boy. All work and no play makes jack a dull boy."
stopWords = set(stopwords.words('english'))
words = df3['tokenized_sents']
wordsFiltered = []

for w in words:
    if w not in stopWords:
        wordsFiltered.append(w)

print(wordsFiltered)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3420/1779903847.py in <module>
#       5
#       6 for w in words:
# ----> 7     if w not in stopWords:
#       8         wordsFiltered.append(w)
#       9
#
# TypeError: unhashable type: 'list'

# %%
df3['stop_words'] = df3['articles'].apply(lambda row: if row not in stopWords)
# Out:
#   File "C:\Users\Marwan\AppData\Local\Temp/ipykernel_3420/2697493760.py", line 1
#     df3['stop_words'] = df3['articles'].apply(lambda row: if row not in stopWords)
#                                                           ^
# SyntaxError: invalid syntax
